# %%
from pynq import Overlay
Overlay("base.bit").download()
# Create new audio object
from pynq.drivers import Audio
pAudio = Audio()

# %%
# monitor configuration: 640*480 @ 60Hz
from pynq.drivers.video import HDMI
hdmi_out = HDMI('out', video_mode=HDMI.VMODE_640x480)
hdmi_out.start()

# %%
# monitor (output) frame buffer size
frame_out_w = 1920
frame_out_h = 1080
# camera (input) configuration
frame_in_w = 640
frame_in_h = 480

# %%
# initialize camera from OpenCV
from pynq.drivers.video import Frame
import cv2

videoIn = cv2.VideoCapture(0)
videoIn.set(cv2.CAP_PROP_FRAME_WIDTH, frame_in_w);
videoIn.set(cv2.CAP_PROP_FRAME_HEIGHT, frame_in_h);

print("capture device is open: " + str(videoIn.isOpened()))
# Out:
# capture device is open: True

# %%
#Capture webcam image
import numpy as np

ret, frame_vga = videoIn.read()

# Display webcam image via HDMI Out
if (ret):
    frame_1080p = np.zeros((1080,1920,3)).astype(np.uint8)       
    frame_1080p[0:480,0:640,:] = frame_vga[0:480,0:640,:]
    hdmi_out.frame_raw(bytearray(frame_1080p.astype(np.int8)))
else:
    print("Error while reading from camera")

# %%
# Output webcam image as JPEG
# %matplotlib inline 
from matplotlib import pyplot as plt
import numpy as np
plt.imshow(frame_vga[:,:,[2,1,0]])
plt.show()

# %%
import cv2

np_frame = frame_vga

face_cascade = cv2.CascadeClassifier(
                        './data/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier(
                        './data/haarcascade_eye.xml')

gray = cv2.cvtColor(np_frame, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
for (x,y,w,h) in faces:
    cv2.rectangle(np_frame,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = np_frame[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)

# %%
# Output OpenCV results via HDMI
frame_1080p[0:480,0:640,:] = frame_vga[0:480,0:640,:]
hdmi_out.frame_raw(bytearray(frame_1080p.astype(np.int8)))

# %%
# Output OpenCV results via matplotlib
# %matplotlib inline 
from matplotlib import pyplot as plt
import numpy as np
plt.imshow(np_frame[:,:,[2,1,0]])
plt.show()

# %%
videoIn.release()
hdmi_out.stop()
del hdmi_out

# %%
# Create new audio object
from pynq.drivers import Audio
pAudio = Audio()

# %%
# devices
from pynq.board import LED
from pynq.board import Switch
import time
led = LED(0)
switch = Switch(0)

# %%
from scipy.io import wavfile
import matplotlib.pyplot as plt
from matplotlib.pyplot import specgram
from time import sleep
# Load a sample
pAudio.load("prologue_of_King_glory.wav")

# %%
videoIn.open(0)
while switch.read():
    ret, frame_vga = videoIn.read()
    gray = cv2.cvtColor(frame_vga, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    # print(len(faces))
    if len(faces) > 0:
        pAudio.play()
    else:
        led.off()
    time.sleep(.05)
videoIn.release()

# %%
rate, x =wavfile.read(".//prologue_of_King_glory.wav")
plt.ion()
plt.figure(1)
plt.plot(x[:100000])
plt.draw()
sleep(0.1)
plt.figure(2)
specgram(x[:100000],Fs=rate,xextent=(0,100))
plt.xlabel('time')
plt.ylabel('frequency')
plt.draw()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-41927c99c13e> in <module>()
#       6 sleep(0.1)
#       7 plt.figure(2)
# ----> 8 specgram(x[:100000],Fs=rate,xextent=(0,100))
#       9 plt.xlabel('time')
#      10 plt.ylabel('frequency')
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/pyplot.py in specgram(x, NFFT, Fs, Fc, detrend, window, noverlap, cmap, xextent, pad_to, sides, scale_by_freq, mode, scale, vmin, vmax, hold, data, **kwargs)
#    3307                           xextent=xextent, pad_to=pad_to, sides=sides,
#    3308                           scale_by_freq=scale_by_freq, mode=mode, scale=scale,
# -> 3309                           vmin=vmin, vmax=vmax, data=data, **kwargs)
#    3310     finally:
#    3311         ax.hold(washold)
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
#    1814         if pre_doc is None:
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/axes/_axes.py in specgram(self, x, NFFT, Fs, Fc, detrend, window, noverlap, cmap, xextent, pad_to, sides, scale_by_freq, mode, scale, vmin, vmax, **kwargs)
#    7034                                        sides=sides,
#    7035                                        scale_by_freq=scale_by_freq,
# -> 7036                                        mode=mode)
#    7037
#    7038         if scale == 'linear':
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/mlab.py in specgram(x, NFFT, Fs, detrend, window, noverlap, pad_to, sides, scale_by_freq, mode)
#    1323                                       sides=sides,
#    1324                                       scale_by_freq=scale_by_freq,
# -> 1325                                       mode=mode)
#    1326
#    1327     if mode != 'complex':
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/mlab.py in _spectral_helper(x, y, NFFT, Fs, detrend_func, window, noverlap, pad_to, sides, scale_by_freq, mode)
#     741         scaling_factor = 2.
#     742
# --> 743     result = stride_windows(x, NFFT, noverlap, axis=0)
#     744     result = detrend(result, detrend_func, axis=0)
#     745     result, windowVals = apply_window(result, window, axis=0,
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/mlab.py in stride_windows(x, n, noverlap, axis)
#     572
#     573     if x.ndim != 1:
# --> 574         raise ValueError('only 1-dimensional arrays can be used')
#     575     if n == 1 and noverlap == 0:
#     576         if axis == 0:
#
# ValueError: only 1-dimensional arrays can be used
